# %%
print("hello world")
# Out:
# hello world

# %%
#single line comments

# %%
''' multiple  line comment '''
# Out:
# ' multiple  line comment '

# %%
#int

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
a
# Out:
# 10

# %%
a=10
b=-25

# %%
#how to check

# %%
type(a) #type() is a method
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
#float

# %%
a=10.5
b=15.5

# %%
a
# Out:
# 10.5

# %%
type(a)
# Out:
# float

# %%
b
# Out:
# 15.5

# %%
type(b)
# Out:
# float

# %%
print(type(0))
# Out:
# <class 'int'>

# %%
#Boolean

# %%
a=True #logical output is 1
b= False #logical output is 0

# %%
a
# Out:
# True

# %%
b
# Out:
# False

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %%
#String

# %%
a="Peter"

# %%
type(a)
# Out:
# str

# %%
#Complex

# %%
a= 2+ 3j

# %%
type(a)
# Out:
# complex

# %%
#sequence data type

# %%
#list -always in []

# %%
a=[10,20,30,40,True]

# %%
type(a)
# Out:
# list

# %%
#Tupple -always in paranthesis

# %%
b=(10,20,30,40,50,60)

# %%
type(0)
# Out:
# int

# %%
#Set -set always in {}

# %%
c={10,20,30,40,50,50,50,60}

# %%
type(c)
# Out:
# set

# %%
#Dictionary -always in curly braces but in keys and values pair {key:values}

# %%
d={"name":"Peter","age":18,"city":"Amravati"}

# %%
type(d)
# Out:
# dict

# %%
#none data type

# %%
a= None

# %%
type(a)
# Out:
# NoneType

# %%
#Arithmatic operatoers

# %%
#addition

# %%
10+20
# Out:
# 30

# %%
#substraction

# %%
10-20
# Out:
# -10

# %%
#multiplication

# %%
10*20
# Out:
# 200

# %%
#division

# %%
10/20
# Out:
# 0.5

# %%
#floor division - estimate value

# %%
10//20
# Out:
# 0

# %%
#modules

# %%
10%20
# Out:
# 10

# %%
#exponential

# %%
2**2
# Out:
# 4

# %%
#camparative operators

# %%
#equal to - assign operator

# %%
a=10

# %%
City="Amravati"

# %%
City
# Out:
# 'Amravati'

# %%
print(City)
# Out:
# Amravati

# %%
#comaparator

# %%
a=10
b=10

# %%
a==b
# Out:
# True

# %%
#not equal to

# %%
20 != 20
# Out:
# False

# %%
20!=10
# Out:
# True

# %%
#greater than less than

# %%
10>20
# Out:
# False

# %%
10<20
# Out:
# True

# %%
#greater than equal to

# %%
10>=20
# Out:
# False

# %%
10<=20
# Out:
# True

# %%
#logical operator

# %%
#and ///when both condition is true

# %%
10==20 and 20==20
# Out:
# False

# %%
10==10 and 20==20
# Out:
# True

# %%
#or -any one condition is ture

# %%
10==20 or 20==20
# Out:
# True

# %%
#not -reverse the condition

# %%
10==20
# Out:
# False

# %%
not(10==20)
# Out:
# True

# %%
#assign operators

# %%
a=10

# %%
a=a+1

# %%
a
# Out:
# 11

# %%
a+=1

# %%
a
# Out:
# 12

# %%
#print functions

# %%
print("Lost in space")
# Out:
# Lost in space

# %%
a="peter"

# %%
print("Lost in space",a)
# Out:
# Lost in space peter

# %%
b=18

# %%
print("I am", a, "and my age is", b)
# Out:
# I am peter and my age is 18

# %%
print(f"I am {a} and my age is {b}") #f-string
# Out:
# I am peter and my age is 18
