# %%
# !pip install pandas

# %% [markdown]
# - build on numpy library
# - deals with the series and dataframe

# %%
import numpy as np
import pandas as pd  ## panel data

# %%
## Series

# %%
data=[10,20,30,40,50] # List

# %%
data
# Out:
# [10, 20, 30, 40, 50]

# %%
pd.Series(data)           ## single colun and multiple rows called as series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# With index name

# %%
pd.Series(data,index=['a','b','c','d','e'])
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
np.array(data)
# Out:
# array([10, 20, 30, 40, 50])

# %%
# dictionary to Series

# %%
data={"a":10,'b': 20, 'c': 30}

# %%
data
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data,name="My Series" )
# Out:
# a    10
# b    20
# c    30
# Name: My Series, dtype: int64

# %%
# DataFrame

# %%
data={
    "name":["Rahul","Tushar","Parth"],
    "Age":[20,21,22],
    "City":["Mumbai","Pune","Delhi"]

}

# %%
pd.Series(data)
# Out:
# name    [Rahul, Tushar, Parth]
# Age               [20, 21, 22]
# City     [Mumbai, Pune, Delhi]
# dtype: object

# %%
pd.Series(data,name="My Series")
# Out:
# name    [Rahul, Tushar, Parth]
# Age               [20, 21, 22]
# City     [Mumbai, Pune, Delhi]
# Name: My Series, dtype: object

# %%
pd.DataFrame(data)
# Out:
#      name  Age    City
# 0   Rahul   20  Mumbai
# 1  Tushar   21    Pune
# 2   Parth   22   Delhi

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      name  Age    City
# 0   Rahul   20  Mumbai
# 1  Tushar   21    Pune
# 2   Parth   22   Delhi

# %%
df=pd.DataFrame(data, index=[1,2,3],columns=["City","Age","name"])

# %%
df
# Out:
#      City  Age    name
# 1  Mumbai   20   Rahul
# 2    Pune   21  Tushar
# 3   Delhi   22   Parth

# %%
data={
    "name":["Rahul","Tushar","Parth"],
    "Age":[20,21,22],
    "City":["Mumbai","Pune","Delhi"]

}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      name  Age    City
# 0   Rahul   20  Mumbai
# 1  Tushar   21    Pune
# 2   Parth   22   Delhi

# %%
# attributes .index      - index labels

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# .columns

# %%
df.columns
# Out:
# Index(['name', 'Age', 'City'], dtype='object')

# %%
df.size
# Out:
# 9

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
# .dtypes

# %%
df.dtypes
# Out:
# name    object
# Age      int64
# City    object
# dtype: object

# %%
# df.shape

# %%
df.shape
# Out:
# (3, 3)

# %%
# .ndim

# %%
df.ndim # is the nom of dimensions
# Out:
# 2

# %%
# df.size - total elements

# %%
df.size
# Out:
# 9

# %%
# .values

# %%
df.values
# Out:
# array([['Rahul', 20, 'Mumbai'],
#        ['Tushar', 21, 'Pune'],
#        ['Parth', 22, 'Delhi']], dtype=object)

# %% [markdown]
# Methods

# %%
# .head  - top rows from head

# %%
df.head()
# Out:
#      name  Age    City
# 0   Rahul   20  Mumbai
# 1  Tushar   21    Pune
# 2   Parth   22   Delhi

# %%
# .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
# df.tail - last 5 rows

# %%
df.tail(1)
# Out:
#     name  Age   City
# 2  Parth   22  Delhi

# %%
# df.isnull()

# %%
df.isnull()
# Out:
#     name    Age   City
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False

# %%
# .describe()

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   21.0
# std     1.0
# min    20.0
# 25%    20.5
# 50%    21.0
# 75%    21.5
# max    22.0

# %%
df.describe(include="all")
# Out:
#          name   Age    City
# count       3   3.0       3
# unique      3   NaN       3
# top     Rahul   NaN  Mumbai
# freq        1   NaN       1
# mean      NaN  21.0     NaN
# std       NaN   1.0     NaN
# min       NaN  20.0     NaN
# 25%       NaN  20.5     NaN
# 50%       NaN  21.0     NaN
# 75%       NaN  21.5     NaN
# max       NaN  22.0     NaN

# %%
# .sample - randomly selects the requirment details

# %%
df.sample(2)
# Out:
#     name  Age    City
# 0  Rahul   20  Mumbai
# 2  Parth   22   Delhi

# %%
#pandas read function  # csv = comma sepetrated values

# %%
df =pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sample(5)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1589    -121.29     38.68                20.0       1881.0           378.0
# 1191    -122.57     38.11                32.0       3521.0           748.0
# 2073    -120.66     35.29                16.0       2272.0           629.0
# 2172    -118.41     33.85                16.0       6123.0          1989.0
# 409     -117.25     32.74                36.0       3548.0           956.0
#
#       population  households  median_income  median_house_value
# 1589       921.0       360.0         1.8589            144000.0
# 1191      1706.0       723.0         3.4705            228600.0
# 2073      1689.0       649.0         1.7031            195000.0
# 2172      2853.0      1789.0         4.4250            336400.0
# 409       1648.0       866.0         2.6962            288200.0

# %%
# single column access

# %%
df["housing_median_age"]
# Out:
# 0       27.0
# 1       43.0
# 2       27.0
# 3       28.0
# 4       19.0
#         ...
# 2995    23.0
# 2996    27.0
# 2997    10.0
# 2998    40.0
# 2999    42.0
# Name: housing_median_age, Length: 3000, dtype: float64

# %%
# multiple columns

# %%
df[["housing_median_age","total_rooms"]]
# Out:
#       housing_median_age  total_rooms
# 0                   27.0       3885.0
# 1                   43.0       1510.0
# 2                   27.0       3589.0
# 3                   28.0         67.0
# 4                   19.0       1241.0
# ...                  ...          ...
# 2995                23.0       1450.0
# 2996                27.0       5257.0
# 2997                10.0        956.0
# 2998                40.0         96.0
# 2999                42.0       1765.0
#
# [3000 rows x 2 columns]

# %%
# .iloc - index location

# %%
df.iloc[12]
# Out:
# longitude               -121.93
# latitude                  37.25
# housing_median_age        36.00
# total_rooms             1089.00
# total_bedrooms           182.00
# population               535.00
# households               170.00
# median_income              4.69
# median_house_value    252600.00
# Name: 12, dtype: float64

# %%
df.iloc[1]
# Out:
# longitude               -118.300
# latitude                  34.260
# housing_median_age        43.000
# total_rooms             1510.000
# total_bedrooms           310.000
# population               809.000
# households               277.000
# median_income              3.599
# median_house_value    176500.000
# Name: 1, dtype: float64

# %%
df.loc[3]
# Out:
# longitude               -118.3600
# latitude                  33.8200
# housing_median_age        28.0000
# total_rooms               67.0000
# total_bedrooms            15.0000
# population                49.0000
# households                11.0000
# median_income              6.1359
# median_house_value    330000.0000
# Name: 3, dtype: float64

# %%
df['housing_median_age'].describe()
# Out:
# count    3000.000000
# mean       28.845333
# std        12.555396
# min         1.000000
# 25%        18.000000
# 50%        29.000000
# 75%        37.000000
# max        52.000000
# Name: housing_median_age, dtype: float64

# %%
df["housing_median_age"]<5
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: housing_median_age, Length: 3000, dtype: bool

# %%
df[df['housing_median_age']<2]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 842     -117.95     35.08                 1.0         83.0            15.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
#
#       population  households  median_income  median_house_value
# 842         32.0        15.0          4.875            141700.0
# 1115         8.0         2.0          1.625             55000.0

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sort_values(by="housing_median_age")      #- where form you need to sort
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 842     -117.95     35.08                 1.0         83.0            15.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 2452    -117.64     33.87                 2.0      17470.0          2727.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 1050    -121.96     37.74                 2.0        200.0            20.0
# ...         ...       ...                 ...          ...             ...
# 26      -122.42     37.76                52.0       3587.0          1030.0
# 36      -122.53     37.97                52.0       1560.0           451.0
# 2965    -122.44     37.71                52.0       2711.0           591.0
# 2970    -122.47     37.77                52.0       2241.0           443.0
# 2972    -118.14     34.17                52.0       2667.0           486.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sort_values(by="median_house_value",ascending=True)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2001    -117.16     32.71                52.0        845.0           451.0
# 1031    -123.08     40.40                10.0        365.0           102.0
# 2740    -119.97     36.44                18.0       1128.0           237.0
# 734     -117.65     35.00                36.0       1184.0           316.0
# 2555    -122.06     37.39                22.0       1236.0           290.0
# ...         ...       ...                 ...          ...             ...
# 2999    -119.63     34.42                42.0       1765.0           263.0
# 2152    -118.43     33.96                20.0       1901.0           270.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2968    -119.23     34.17                18.0       6171.0          1490.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
#
#       population  households  median_income  median_house_value
# ...

# %%
house_age_data=df.sort_values("housing_median_age")

# %%
house_age_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 842     -117.95     35.08                 1.0         83.0            15.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 2452    -117.64     33.87                 2.0      17470.0          2727.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 1050    -121.96     37.74                 2.0        200.0            20.0
# ...         ...       ...                 ...          ...             ...
# 26      -122.42     37.76                52.0       3587.0          1030.0
# 36      -122.53     37.97                52.0       1560.0           451.0
# 2965    -122.44     37.71                52.0       2711.0           591.0
# 2970    -122.47     37.77                52.0       2241.0           443.0
# 2972    -118.14     34.17                52.0       2667.0           486.0
#
#       population  households  median_income  median_house_value
# ...

# %%
house_age_data=df.sort_index()      #- original index ko vapas lata he

# %%
house_age_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
house_age_data=df.reset_index()      #- original index ko vapas lata he aur rest ko bhi sath me print krta he

# %%
house_age_data
# Out:
#       index  longitude  latitude  housing_median_age  total_rooms  \
# 0         0    -122.05     37.37                27.0       3885.0
# 1         1    -118.30     34.26                43.0       1510.0
# 2         2    -117.81     33.78                27.0       3589.0
# 3         3    -118.36     33.82                28.0         67.0
# 4         4    -119.67     36.33                19.0       1241.0
# ...     ...        ...       ...                 ...          ...
# 2995   2995    -119.86     34.42                23.0       1450.0
# 2996   2996    -118.14     34.06                27.0       5257.0
# 2997   2997    -119.70     36.30                10.0        956.0
# 2998   2998    -117.12     34.10                40.0         96.0
# 2999   2999    -119.63     34.42                42.0       1765.0
#
#       total_bedrooms  population  households  median_income  \
# 0              661.0      1537.0       606.0         6.6085
# ...

# %%
df["new_age"]=df["housing_median_age"]*2

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
# deleting the columns
df.drop(columns="new_age")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.drop("longitude", axis=1)
# Out:
#       latitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 0        37.37                27.0       3885.0           661.0      1537.0
# 1        34.26                43.0       1510.0           310.0       809.0
# 2        33.78                27.0       3589.0           507.0      1484.0
# 3        33.82                28.0         67.0            15.0        49.0
# 4        36.33                19.0       1241.0           244.0       850.0
# ...        ...                 ...          ...             ...         ...
# 2995     34.42                23.0       1450.0           642.0      1258.0
# 2996     34.06                27.0       5257.0          1082.0      3496.0
# 2997     36.30                10.0        956.0           201.0       693.0
# 2998     34.10                40.0         96.0            14.0        46.0
# 2999     34.42                42.0       1765.0           263.0       753.0
#
# ...

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df.drop(columns="new_age",inplace=True)

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
data
# Out:
# {'name': ['Rahul', 'Tushar', 'Parth'],
#  'Age': [20, 21, 22],
#  'City': ['Mumbai', 'Pune', 'Delhi']}

# %%
df.rename(columns={0:"column1"})
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.rename(columns={"total_bedrooms":"column1"})
# Out:
#       longitude  latitude  housing_median_age  total_rooms  column1  \
# 0       -122.05     37.37                27.0       3885.0    661.0
# 1       -118.30     34.26                43.0       1510.0    310.0
# 2       -117.81     33.78                27.0       3589.0    507.0
# 3       -118.36     33.82                28.0         67.0     15.0
# 4       -119.67     36.33                19.0       1241.0    244.0
# ...         ...       ...                 ...          ...      ...
# 2995    -119.86     34.42                23.0       1450.0    642.0
# 2996    -118.14     34.06                27.0       5257.0   1082.0
# 2997    -119.70     36.30                10.0        956.0    201.0
# 2998    -117.12     34.10                40.0         96.0     14.0
# 2999    -119.63     34.42                42.0       1765.0    263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# ...

# %% [markdown]
# Missing Values

# %%
df.isnull()        #- check missing values
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.notnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          True      True                True         True            True
# 1          True      True                True         True            True
# 2          True      True                True         True            True
# 3          True      True                True         True            True
# 4          True      True                True         True            True
# ...         ...       ...                 ...          ...             ...
# 2995       True      True                True         True            True
# 2996       True      True                True         True            True
# 2997       True      True                True         True            True
# 2998       True      True                True         True            True
# 2999       True      True                True         True            True
#
#       population  households  median_income  median_house_value
# ...

# %%
df.notnull().sum()
# Out:
# longitude             3000
# latitude              3000
# housing_median_age    3000
# total_rooms           3000
# total_bedrooms        3000
# population            3000
# households            3000
# median_income         3000
# median_house_value    3000
# dtype: int64

# %%
### Replcaing the null values

# %%
df.fillna(0)     # null values ko fill kiya jayega
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# df.dropna()
df.dropna(inplace=True)

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# Aghregation functions

# %%
df['total_rooms'].sum()
# Out:
# np.float64(7798736.0)

# %%
df["total_rooms"].mean()
# Out:
# np.float64(2599.578666666667)

# %%
df["total_rooms"].max()
# Out:
# 30450.0

# %%
df.groupby("housing_median_age").mean()
# Out:
#                      longitude   latitude  total_rooms  total_bedrooms  \
# housing_median_age
# 1.0                -117.450000  34.470000    44.500000        8.500000
# 2.0                -119.596667  35.793333  9006.333333     1459.166667
# 3.0                -119.389167  35.591667  6731.250000     1214.750000
# 4.0                -118.963571  34.962857  7383.392857     1385.214286
# 5.0                -119.550513  35.870769  5660.615385     1085.051282
# 6.0                -119.419600  35.573200  5255.040000     1001.400000
# 7.0                -118.853000  35.096500  3718.250000      646.500000
# 8.0                -118.952000  35.499200  3311.520000      617.240000
# 9.0                -119.241111  35.755556  3407.888889      646.111111
# 10.0               -119.763667  36.084000  3294.500000      671.166667
# 11.0               -119.400732  35.748780  3483.170732      703.146341
# 12.0               -119.129268  35.385122  4032.731707      810.341463
# ...

# %%
df1=df.groupby(["housing_median_age","total_bedrooms"])

# %%
df1.mean()
# Out:
#                                    longitude  latitude  total_rooms  \
# housing_median_age total_bedrooms
# 1.0                2.0               -116.95     33.86          6.0
#                    15.0              -117.95     35.08         83.0
# 2.0                20.0              -121.96     37.74        200.0
#                    43.0              -122.29     37.82        158.0
#                    98.0              -117.51     34.16        718.0
# ...                                      ...       ...          ...
# 52.0               1030.0            -122.42     37.76       3587.0
#                    1100.0            -122.42     37.79       3364.0
#                    1192.0            -122.42     37.76       4407.0
#                    1268.0            -122.44     37.77       5604.0
#                    1566.0            -122.43     37.79       6186.0
#
#                                    population  households  median_income  \
# housing_median_age total_bedrooms
# ...

# %%
df["housing_median_age"].value_counts()
# Out:
# housing_median_age
# 52.0    173
# 35.0    118
# 36.0    115
# 16.0    107
# 34.0    102
# 17.0    100
# 32.0     91
# 37.0     88
# 26.0     88
# 25.0     86
# 33.0     85
# 15.0     77
# 30.0     76
# 19.0     76
# 18.0     76
# 24.0     75
# 29.0     75
# 27.0     74
# 38.0     64
# 20.0     63
# 21.0     61
# 22.0     60
# 28.0     58
# 31.0     57
# 14.0     57
# 43.0     56
# 41.0     56
# 39.0     55
# 23.0     53
# 45.0     51
# 44.0     51
# 42.0     51
# 40.0     43
# 13.0     41
# 46.0     41
# 12.0     41
# 11.0     41
# 5.0      39
# 48.0     34
# 10.0     30
# 4.0      28
# 9.0      27
# 8.0      25
# 6.0      25
# 47.0     22
# 49.0     21
# 7.0      20
# 50.0     16
# 3.0      12
# 51.0     11
# 2.0       6
# 1.0       2
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
titanic =sns.load_dataset("titanic")

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
titanic.size
# Out:
# 13365

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic.groupby("sex")["survived"].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
titanic.groupby("sex")["survived"].mean()*100
# Out:
# sex
# female    74.203822
# male      18.890815
# Name: survived, dtype: float64

# %%
# ()- categorical columns
# ()- numerical columns   -exel ke onse columns ko kis brackets me dalna he

# %%
titanic.groupby(["sex","pclass"])["survived"].mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
titanic.groupby(["sex","pclass"])["survived"].mean().unstack()
# Out:
# pclass         1         2         3
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
sns.pairplot(titanic, hue="survived") # Using 'survived' as the hue
# or
sns.pairplot(titanic, hue="sex") # Using 'sex' as the hue
