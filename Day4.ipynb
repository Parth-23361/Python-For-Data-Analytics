# %%
##Functions

# %% [markdown]
# functions is the block of codes
#
# // built in functions

# %%
print('hello')
# Out:
# hellow

# %%
len('hello')
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
int(45.6)
# Out:
# 45

# %%
float(45)
# Out:
# 45.0

# %%
str(12334)
# Out:
# '12334'

# %%
age=int(input('enter your age:-'))
# Out:
# enter your age:-23

# %%
name="tushar"

# %%
print(name)
# Out:
# tushar

# %%
min([1,2,3,4,5,6,7])
# Out:
# 1

# %%
max([8,9,10,11])
# Out:
# 11

# %%
sum([1,3,4,5,56,6,78,])
# Out:
# 153

# %%
sorted([3,6,5,7,4,5,32,1,3,54,6,8])
# Out:
# [1, 3, 3, 4, 5, 5, 6, 6, 7, 8, 32, 54]

# %%
abs(-10) #absolute is give us positive value only
# Out:
# 10

# %%
# user define functions

# %% [markdown]
# - def keyword use for the define the function name
# - syntax - def function name(callable values):
# - function name always in lowercase

# %%
def greeting(name):
   print("hello",name)

# %%
greeting('tushar')
# Out:
# hello tushar

# %%
greeting("peter")
# Out:
# hello peter

# %%
def square(num):
 return num*num

# %%
square(12)
# Out:
# 144

# %%
square(2)
# Out:
# 4

# %%
def greet(name="guest"):      ## default paramter
  print("hello",name)

# %%
greet('peter')
# Out:
# hello peter

# %%
def add(a,b):
  int(input("enter the value of a"))
  int(input("enter the value of b"))  ### mistakes in inputs
  return a+b

# %%
add (4,6) ## showing value error means not useful
# Out:
# enter the value of a2
# enter the value of b3
# 10

# %%
# external function

# %%
import math

# %%
math.sqrt(0)
# Out:
# 0.0

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.degrees(180)
# Out:
# 10313.240312354817

# %%
math.sin(40)
# Out:
# 0.7451131604793488

# %%
math.log(10)
# Out:
# 2.302585092994046

# %%
## above me importing library for the external fucntijons

# %% [markdown]
# Important Labda/ Map/ Fiter

# %%
## we called as anonymous function- without name

# %%
square=lambda a:a*a

# %%
square(5)
# Out:
# 25

# %%
cube=lambda a:a*a*a    ## lambda it the keyword like (true, false, in)

# %%
cube(5)
# Out:
# 125

# %%
# one line comment

# %%
add=lambda a,b : a+b

# %%
add(54,46)
# Out:
# 100

# %%
square=lambda a: a*a

# %%
square(1)
# Out:
# 1

# %%
power=lambda a,b:a**b

# %%
power(2,10)
# Out:
# 1024

# %%
num=[1,2,3,4,5,6,7,8]

# %%
num
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# map - it applies a function to each item in list

# %%
square=list(map(lambda a:a*a,num))

# %%
square
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
# ()- paranthesis
# []- square braces
# {}- curly braces

# %%
#fliter()- filter the items

# %%
square=list(filter(lambda a:a%2==0,num))

# %%
square
# Out:
# [2, 4, 6, 8]

# %%
even_num=[]
for i in num:
   if i%2==0:
     even_num.append(i)

# %%
print(even_num)
# Out:
# [2, 4, 6, 8]

# %%
square=list(map(lambda x: x*x, filter(lambda x:x%2==0,num)))

# %%
square
# Out:
# [4, 16, 36, 64]

# %%
tuple(a)
# Out:
# ('t', 'u', 's', 'h', 'a', 'r')

# %%
list(a)
# Out:
# ['t', 'u', 's', 'h', 'a', 'r']

# %%
set(a)
# Out:
# {'a', 'h', 'r', 's', 't', 'u'}
